# %% [markdown]
# ## Creating SQLite Database

# %%
# Import libraries
import pandas as pd
import sqlite3

# %%
# Install the ipthon-sql òlibrary
#!pip install ipython-sql

# %%
# To guarantee compatibility between jupysql / ipython-sql and newer prettytable releases
#!pip install "prettytable<3.10"

# %%
#CANCELLARE !pip install --upgrade ipython-sql prettytable

# %%
# Import data
df = pd.read_csv("WorldLifeExpectancy.csv")
# df.head()

# %%
# Create a connetion using sqlite3 library
cnn = sqlite3.connect('World_Life_Expectancy.db')

# %%
# Add data to the database
df.to_sql('World_Life_Expectancy', cnn)
# Out:
# 2941

# %%
# Load the sql module to Ipython
# %load_ext sql

# %%
# Point the jupiter sql library to the database
# %sql sqlite:///World_Life_Expectancy.db

# Set a compatible style
# %config SqlMagic.style = 'PLAIN_COLUMNS'

# Tell sql to output to a Pandas DataFrame directly
# %config SqlMagic.autopandas = True

# %%
# %%sql
#
# SELECT *
# FROM World_Life_Expectancy
# Out:
#  * sqlite:///World_Life_Expectancy.db
# Done.
#       index      Country  Year      Status  Life expectancy   Adult Mortality  \
# 0         0  Afghanistan  2022  Developing              65.0              263
# 1         1  Afghanistan  2021  Developing              59.9              271
# 2         2  Afghanistan  2020  Developing              59.9              268
# 3         3  Afghanistan  2019  Developing              59.5              272
# 4         4  Afghanistan  2018  Developing               NaN              275
# ...     ...          ...   ...         ...               ...              ...
# 2936   2936     Zimbabwe  2011  Developing              44.3              723
# 2937   2937     Zimbabwe  2010  Developing              44.5              715
# 2938   2938     Zimbabwe  2009  Developing              44.8               73
# 2939   2939     Zimbabwe  2008  Developing              45.3              686
# 2940   2940     Zimbabwe  2007  Developing              46.0              665
#
#       infant deaths  percentage expenditure  Measles    BMI   \
# 0                62                    71.3      1154   19.1
# 1                64                    73.5       492   18.6
# 2                66                    73.2       430   18.1
# 3                69                    78.2      2787   17.6
# 4                71                     7.1      3013   17.2
# ...             ...                     ...       ...    ...
# 2936             27                     0.0        31   27.1
# 2937             26                     0.0       998   26.7
# 2938             25                     0.0       304   26.3
# 2939             25                     0.0       529   25.9
# 2940             24                     0.0      1483   25.5
#
#       under-five deaths   Polio  Diphtheria    HIV/AIDS  GDP  \
# 0                     83      6           65        0.1  584
# 1                     86     58           62        0.1  613
# 2                     89     62           64        0.1  632
# 3                     93     67           67        0.1  670
# 4                     97     68           68        0.1   64
# ...                  ...    ...          ...        ...  ...
# 2936                  42     67           65       33.6  454
# 2937                  41      7           68       36.7  453
# 2938                  40     73           71       39.8   57
# 2939                  39     76           75       42.1  549
# 2940                  39     78           78       43.5  547
#
#        thinness  1-19 years   thinness 5-9 years  Schooling  Row_ID
# 0                      17.2                 17.3       10.1       1
# 1                      17.5                 17.5       10.0       2
# 2                      17.7                 17.7        9.9       3
# 3                      17.9                 18.0        9.8       4
# 4                      18.2                 18.2        9.5       5
# ...                     ...                  ...        ...     ...
# 2936                    9.4                  9.4        9.2    2937
# 2937                    9.8                  9.9        9.5    2938
# 2938                    1.2                  1.3       10.0    2939
# 2939                    1.6                  1.7        9.8    2940
# 2940                   11.0                 11.2        9.8    2941
#
# [2941 rows x 19 columns]

# %% [markdown]
# ## Data Cleaning
#
# The aim of data cleaning is to enhance the quality and reliability of a dataset by detecting and correcting errors or inconsistencies. The overall goal is to prepare the data so it can be trusted and effectively used for analysis, modeling, or decision-making. Examples include handling duplicate records, missing values, or invalid entries such as zeros where they are not appropriate.

# %%
# %%sql
#
# -- Count all rows
#
# SELECT COUNT(*) AS total_rows
# FROM World_Life_Expectancy
# Out:
#  * sqlite:///World_Life_Expectancy.db
# Done.
#    total_rows
# 0        2941

# %%
# %%sql
#
# -- Standardize column names
#
# ALTER TABLE World_Life_Expectancy RENAME COLUMN "Life expectancy " TO "Life_expectancy";
# ALTER TABLE World_Life_Expectancy RENAME COLUMN "Adult Mortality" TO "Adult_mortality";
# ALTER TABLE World_Life_Expectancy RENAME COLUMN "infant deaths" TO "Infant_deaths";
# ALTER TABLE World_Life_Expectancy RENAME COLUMN "percentage expenditure" TO "Percentage_expenditure";
# ALTER TABLE World_Life_Expectancy RENAME COLUMN " BMI " TO "BMI";
# ALTER TABLE World_Life_Expectancy RENAME COLUMN "under-five deaths " TO "Under_five_deaths";
# ALTER TABLE World_Life_Expectancy RENAME COLUMN " HIV/AIDS" TO "hiv_aids";
# ALTER TABLE World_Life_Expectancy RENAME COLUMN " thinness  1-19 years" TO "Thinness_1_19_years";
# ALTER TABLE World_Life_Expectancy RENAME COLUMN " thinness 5-9 years" TO "Thinness_5_9_years";
# Out:
#  * sqlite:///World_Life_Expectancy.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
#
# -- Country and Year values should be unique
#
# SELECT Country, Year, CONCAT(Country, Year), COUNT(CONCAT(Country, Year))
# FROM World_Life_Expectancy
# GROUP BY Country, Year, CONCAT(Country, Year)
# HAVING COUNT(CONCAT(Country, Year)) > 1
# Out:
#  * sqlite:///World_Life_Expectancy.db
# Done.
#     Country  Year CONCAT(Country, Year)  COUNT(CONCAT(Country, Year))
# 0   Ireland  2022           Ireland2022                             2
# 1   Senegal  2009           Senegal2009                             2
# 2  Zimbabwe  2019          Zimbabwe2019                             2

# %%
# %%sql
#
# -- Identify the IDs corresponding to the Year + Country combinations that have duplicate values in order to remove them from the data
#
# SELECT *
# FROM(
# SELECT Row_ID,
# CONCAT(Country, Year),
# ROW_NUMBER() OVER(PARTITION BY CONCAT(Country, Year) ORDER BY CONCAT(Country, Year)) as Row_Num
# FROM World_Life_Expectancy
# ) AS Row_Table
# WHERE Row_Num > 1
# Out:
#  * sqlite:///World_Life_Expectancy.db
# Done.
#    Row_ID CONCAT(Country, Year)  Row_Num
# 0    1252           Ireland2022        2
# 1    2265           Senegal2009        2
# 2    2929          Zimbabwe2019        2

# %%
# %%sql
#
# -- Remove IDs from the table
#
# DELETE FROM World_Life_Expectancy
# WHERE Row_ID IN (
# 	SELECT Row_ID
# 	FROM(
# 	SELECT Row_ID,
# 	CONCAT(Country, Year),
# 	ROW_NUMBER() OVER(PARTITION BY CONCAT(Country, Year) ORDER BY CONCAT(Country, Year)) as Row_Num
# 	FROM World_Life_Expectancy
# 	) AS Row_Table
# 	WHERE Row_Num > 1
# )
# Out:
#  * sqlite:///World_Life_Expectancy.db
# 3 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
#
# -- Check for any missing or null values in the Status column
#
# SELECT *
# FROM World_Life_Expectancy
# WHERE Status IS NULL
# Out:
#  * sqlite:///World_Life_Expectancy.db
# Done.
#    index                   Country  Year Status  Life_expectancy  \
# 0      8               Afghanistan  2014   None             57.5
# 1     17                   Albania  2021   None             77.5
# 2    988                   Georgia  2012   None             73.9
# 3    990                   Georgia  2010   None             72.7
# 4   2797  United States of America  2021   None             79.1
# 5   2846                   Vanuatu  2020   None             71.6
# 6   2914                    Zambia  2016   None             57.4
# 7   2918                    Zambia  2012   None             49.3
#
#    Adult_mortality  Infant_deaths  Percentage_expenditure  Measles    BMI  \
# 0              295             82                    10.9      1141  15.2
# 1                8              0                   428.7         0  57.2
# 2              128              1                     9.4      1356  48.6
# 3              132              1                    70.5       216  47.5
# 4               14             23                     0.0       667  69.1
# 5              135              0                   447.5         0  51.7
# 6              368             30                   143.9        26   2.2
# 7              554             34                   121.9        45  18.4
#
#    Under_five_deaths  Polio  Diphtheria   hiv_aids   GDP  Thinness_1_19_years  \
# 0                113     63           63       0.1   370                 19.0
# 1                  1     98           98       0.1  4576                  1.2
# 2                  1     82           82       0.1   154                  2.8
# 3                  2     74           75       0.1   928                  2.9
# 4                 27     93           95       0.1     0                  0.8
# 5                  0     65           64       0.1  3167                  1.5
# 6                 47     93           94       9.1  1139                  6.7
# 7                 55     84           82      17.0   691                  7.1
#
#    Thinness_5_9_years  Schooling  Row_ID
# 0                19.1        8.4       9
# 1                 1.3       14.2      18
# 2                 2.9       12.2     989
# 3                 3.0       11.8     991
# 4                 0.6        0.0    2798
# 5                 1.4       10.8    2847
# 6                 6.6       11.6    2915
# 7                 7.0       10.7    2919

# %%
# %%sql
#
# -- Check for non-null values in the status column.
#
# SELECT DISTINCT(Status)
# FROM World_Life_Expectancy
# WHERE Status <> ''
# Out:
#  * sqlite:///World_Life_Expectancy.db
# Done.
#        Status
# 0  Developing
# 1   Developed

# %%
# %%sql
#
# -- Update the values of the rows where the status is null, based on the status information recorded in other rows for the same country
#
# UPDATE World_Life_Expectancy
# SET Status = 'Developing'
# WHERE Status IS NULL
#   AND Country IN (
#       SELECT Country
#       FROM World_Life_Expectancy
#       WHERE Status = 'Developing'
#   )
# ;
#
# UPDATE World_Life_Expectancy
# SET Status = 'Developed'
# WHERE Status IS NULL
#   AND Country IN (
#       SELECT Country
#       FROM World_Life_Expectancy
#       WHERE Status = 'Developed'
#   )
# Out:
#  * sqlite:///World_Life_Expectancy.db
# 7 rows affected.
# 1 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
#
# -- Check for any missing or null values in the Life Expectancy column
#
# SELECT *
# FROM World_Life_Expectancy
# WHERE Life_expectancy IS NULL
# Out:
#  * sqlite:///World_Life_Expectancy.db
# Done.
#    index      Country  Year      Status Life_expectancy  Adult_mortality  \
# 0      4  Afghanistan  2018  Developing            None              275
# 1     20      Albania  2018  Developing            None               88
#
#    Infant_deaths  Percentage_expenditure  Measles    BMI  Under_five_deaths  \
# 0             71                     7.1      3013  17.2                 97
# 1              0                   437.1        28  55.1                  1
#
#    Polio  Diphtheria   hiv_aids   GDP  Thinness_1_19_years  \
# 0     68           68       0.1    64                 18.2
# 1     99           99       0.1  4437                  1.4
#
#    Thinness_5_9_years  Schooling  Row_ID
# 0                18.2        9.5       5
# 1                 1.5       13.3      21

# %%
# %%sql
#
# -- For Afghanistan and Albania, we can see a gradual increase in life expectancy over the years, so we can replace the null value with
# -- the mean average of the values from the previous and next year
#
# SELECT *
# FROM World_Life_Expectancy
# WHERE Country IN ('Afghanistan', 'Albania')
# Out:
#  * sqlite:///World_Life_Expectancy.db
# Done.
#     index      Country  Year      Status  Life_expectancy  Adult_mortality  \
# 0       0  Afghanistan  2022  Developing             65.0              263
# 1       1  Afghanistan  2021  Developing             59.9              271
# 2       2  Afghanistan  2020  Developing             59.9              268
# 3       3  Afghanistan  2019  Developing             59.5              272
# 4       4  Afghanistan  2018  Developing              NaN              275
# 5       5  Afghanistan  2017  Developing             58.8              279
# 6       6  Afghanistan  2016  Developing             58.6              281
# 7       7  Afghanistan  2015  Developing             58.1              287
# 8       8  Afghanistan  2014  Developing             57.5              295
# 9       9  Afghanistan  2013  Developing             57.3              295
# 10     10  Afghanistan  2012  Developing             57.3              291
# 11     11  Afghanistan  2011  Developing             57.0              293
# 12     12  Afghanistan  2010  Developing             56.7              295
# 13     13  Afghanistan  2009  Developing             56.2                3
# 14     14  Afghanistan  2008  Developing             55.3              316
# 15     15  Afghanistan  2007  Developing             54.8              321
# 16     16      Albania  2022  Developing             77.8               74
# 17     17      Albania  2021  Developing             77.5                8
# 18     18      Albania  2020  Developing             77.2               84
# 19     19      Albania  2019  Developing             76.9               86
# 20     20      Albania  2018  Developing              NaN               88
# 21     21      Albania  2017  Developing             76.2               91
# 22     22      Albania  2016  Developing             76.1               91
# 23     23      Albania  2015  Developing             75.3                1
# 24     24      Albania  2014  Developing             75.9                9
# 25     25      Albania  2013  Developing             74.2               99
# 26     26      Albania  2012  Developing             73.5               15
# 27     27      Albania  2011  Developing             73.0               17
# 28     28      Albania  2010  Developing             72.8               18
# 29     29      Albania  2009  Developing             73.3               15
# 30     30      Albania  2008  Developing             73.6               14
# 31     31      Albania  2007  Developing             72.6               11
#
#     Infant_deaths  Percentage_expenditure  Measles    BMI  Under_five_deaths  \
# 0              62                    71.3      1154  19.1                 83
# 1              64                    73.5       492  18.6                 86
# 2              66                    73.2       430  18.1                 89
# 3              69                    78.2      2787  17.6                 93
# 4              71                     7.1      3013  17.2                 97
# 5              74                    79.7      1989  16.7                102
# 6              77                    56.8      2861  16.2                106
# 7              80                    25.9      1599  15.7                110
# 8              82                    10.9      1141  15.2                113
# 9              84                    17.2      1990  14.7                116
# 10             85                     1.4      1296  14.2                118
# 11             87                    15.3       466  13.8                120
# 12             87                    11.1       798  13.4                122
# 13             88                    16.9      2486  13.0                122
# 14             88                    10.6      8762  12.6                122
# 15             88                    10.4      6532  12.2                122
# 16              0                   365.0         0  58.0                  0
# 17              0                   428.7         0  57.2                  1
# 18              0                   430.9         0  56.5                  1
# 19              0                   412.4         9  55.8                  1
# 20              0                   437.1        28  55.1                  1
# 21              1                    41.8        10  54.3                  1
# 22              1                   348.1         0  53.5                  1
# 23              1                    36.6         0  52.6                  1
# 24              1                    32.2        22  51.7                  1
# 25              1                     3.3        68   5.8                  1
# 26              1                    27.0         6  49.9                  1
# 27              1                   221.8         7  48.9                  1
# 28              1                    14.7         8  47.9                  1
# 29              1                   104.5        16  46.9                  1
# 30              1                    96.2        18  46.0                  1
# 31              1                    91.7       662  45.0                  1
#
#     Polio  Diphtheria   hiv_aids   GDP  Thinness_1_19_years  \
# 0       6           65       0.1   584                 17.2
# 1      58           62       0.1   613                 17.5
# 2      62           64       0.1   632                 17.7
# 3      67           67       0.1   670                 17.9
# 4      68           68       0.1    64                 18.2
# 5      66           66       0.1   553                 18.4
# 6      63           63       0.1   446                 18.6
# 7      64           64       0.1   373                 18.8
# 8      63           63       0.1   370                 19.0
# 9      58           58       0.1   273                 19.2
# 10     58           58       0.1    25                 19.3
# 11      5            5       0.1   219                 19.5
# 12     41           41       0.1   199                 19.7
# 13     36           36       0.1   188                 19.9
# 14     35           33       0.1   118                  2.1
# 15     24           24       0.1   115                  2.3
# 16     99           99       0.1  3954                  1.2
# 17     98           98       0.1  4576                  1.2
# 18     99           99       0.1  4415                  1.3
# 19     99           99       0.1  4248                  1.3
# 20     99           99       0.1  4437                  1.4
# 21     99           99       0.1   494                  1.4
# 22     98           98       0.1  4114                  1.5
# 23     99           99       0.1   438                  1.6
# 24     99           98       0.1   363                  1.6
# 25     97           97       0.1    35                  1.7
# 26     97           98       0.1   279                  1.8
# 27     98           97       0.1  2417                  1.8
# 28     97           97       0.1   190                  1.9
# 29     98           98       0.1  1454                  2.0
# 30     97           97       0.1  1327                  2.1
# 31     97           97       0.1  1176                  2.1
#
#     Thinness_5_9_years  Schooling  Row_ID
# 0                 17.3       10.1       1
# 1                 17.5       10.0       2
# 2                 17.7        9.9       3
# 3                 18.0        9.8       4
# 4                 18.2        9.5       5
# 5                 18.4        9.2       6
# 6                 18.7        8.9       7
# 7                 18.9        8.7       8
# 8                 19.1        8.4       9
# 9                 19.3        8.1      10
# 10                19.5        7.9      11
# 11                19.7        6.8      12
# 12                19.9        6.5      13
# 13                 2.2        6.2      14
# 14                 2.4        5.9      15
# 15                 2.5        5.5      16
# 16                 1.3       14.2      17
# 17                 1.3       14.2      18
# 18                 1.4       14.2      19
# 19                 1.4       14.2      20
# 20                 1.5       13.3      21
# 21                 1.5       12.5      22
# 22                 1.6       12.2      23
# 23                 1.6       12.0      24
# 24                 1.7       11.6      25
# 25                 1.8       11.4      26
# 26                 1.8       10.8      27
# 27                 1.9       10.9      28
# 28                 2.0       10.7      29
# 29                 2.1       10.7      30
# 30                 2.1       10.6      31
# 31                 2.2       10.7      32

# %%
# %%sql
#
# -- For Afghanistan, we can see a gradual increase in life expectancy over the years, so we can replace the null value with
# -- the mean average of the values from the previous and next year
#
# SELECT t1.Country, t1.Year,  t1.Life_expectancy,
# 	t2.Country, t2.Year,  t2.Life_expectancy,
#     t3.Country, t3.Year,  t3.Life_expectancy,
#     ROUND((t2.Life_expectancy + t3.Life_expectancy)/2,1)
# FROM World_Life_Expectancy t1
# JOIN World_Life_Expectancy t2
# 	ON t1.Country = t2.Country
#     AND t1.Year = t2.Year - 1
# JOIN World_Life_Expectancy t3
# 	ON t1.Country = t3.Country
#     AND t1.Year = t3.Year + 1
# WHERE t1.Life_expectancy IS NULL
# Out:
#  * sqlite:///World_Life_Expectancy.db
# Done.
#        Country  Year  Life_expectancy      Country  Year  Life_expectancy  \
# 0  Afghanistan  2018             None  Afghanistan  2019             59.5
# 1      Albania  2018             None      Albania  2019             76.9
#
#        Country  Year  Life_expectancy  \
# 0  Afghanistan  2017             58.8
# 1      Albania  2017             76.2
#
#    ROUND((t2.Life_expectancy + t3.Life_expectancy)/2,1)
# 0                                               59.1
# 1                                               76.6

# %%
# %%sql
#
# -- Update the table with the new averaged values.
#
# UPDATE World_Life_Expectancy AS w
# SET Life_expectancy = (
#   SELECT ROUND((p.Life_expectancy + n.Life_expectancy)/2.0, 1)
#   FROM World_Life_Expectancy AS p
#   JOIN World_Life_Expectancy AS n
#     ON p.Country = n.Country
#    AND p.Year   = w.Year - 1
#    AND n.Year   = w.Year + 1
#   WHERE p.Country = w.Country
# )
# WHERE w.Life_expectancy IS NULL
#   AND EXISTS (
#     SELECT 1
#     FROM World_Life_Expectancy AS p
#     JOIN World_Life_Expectancy AS n
#       ON p.Country = n.Country
#      AND p.Year   = w.Year - 1
#      AND n.Year   = w.Year + 1
#     WHERE p.Country = w.Country
# )
# Out:
#  * sqlite:///World_Life_Expectancy.db
# 2 rows affected.
# Empty DataFrame
# Columns: []
# Index: []
